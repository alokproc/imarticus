# %%
import pandas as pd
import sklearn as sk
from sklearn.neighbors import KNeighborsRegressor

# %%
k_list = range(1, 457)
k_MSE_tuples = []

df = pd.read_csv(r'E:\MYLEARN\2-ANALYTICS-DataScience\datasets\boston.csv')

print(df.shape)
df.head()
# Out:
# (506, 14)
#    crime_rate  proportion_res_land  proportion_business  river"     NO  \
# 0     0.00632                 18.0                 2.31       0  0.538
# 1     0.02731                  0.0                 7.07       0  0.469
# 2     0.02729                  0.0                 7.07       0  0.469
# 3     0.03237                  0.0                 2.18       0  0.458
# 4     0.06905                  0.0                 2.18       0  0.458
#
#    avg_rooms  proportion_units  distance  accessibility  property_tax  \
# 0      6.575              65.2    4.0900              1         296.0
# 1      6.421              78.9    4.9671              2         242.0
# 2      7.185              61.1    4.9671              2         242.0
# 3      6.998              45.8    6.0622              3         222.0
# 4      7.147              54.2    6.0622              3         222.0
#
#    pupil_teacher_ratio  proportion_blacks  lower_status  value
# 0                 15.3             396.90          4.98   24.0
# 1                 17.8             396.90          9.14   21.6
# 2                 17.8             392.83          4.03   34.7
# 3                 18.7             394.63          2.94   33.4
# 4                 18.7             396.90          5.33   36.2

# %%
df.describe()
# Out:
#        crime_rate  proportion_res_land  proportion_business      river"  \
# count  506.000000           506.000000           506.000000  506.000000
# mean     3.613524            11.363636            11.136779    0.069170
# std      8.601545            23.322453             6.860353    0.253994
# min      0.006320             0.000000             0.460000    0.000000
# 25%      0.082045             0.000000             5.190000    0.000000
# 50%      0.256510             0.000000             9.690000    0.000000
# 75%      3.677082            12.500000            18.100000    0.000000
# max     88.976200           100.000000            27.740000    1.000000
#
#                NO   avg_rooms  proportion_units    distance  accessibility  \
# count  506.000000  506.000000        506.000000  506.000000     506.000000
# mean     0.554695    6.284634         68.574901    3.795043       9.549407
# std      0.115878    0.702617         28.148861    2.105710       8.707259
# min      0.385000    3.561000          2.900000    1.129600       1.000000
# 25%      0.449000    5.885500         45.025000    2.100175       4.000000
# 50%      0.538000    6.208500         77.500000    3.207450       5.000000
# 75%      0.624000    6.623500         94.075000    5.188425      24.000000
# max      0.871000    8.780000        100.000000   12.126500      24.000000
#
#        property_tax  pupil_teacher_ratio  proportion_blacks  lower_status  \
# count    506.000000           506.000000         506.000000    506.000000
# mean     408.237154            18.455534         356.674032     12.653063
# std      168.537116             2.164946          91.294864      7.141062
# min      187.000000            12.600000           0.320000      1.730000
# 25%      279.000000            17.400000         375.377500      6.950000
# 50%      330.000000            19.050000         391.440000     11.360000
# 75%      666.000000            20.200000         396.225000     16.955000
# max      711.000000            22.000000         396.900000     37.970000
#
#             value
# count  506.000000
# mean    22.532806
# std      9.197104
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %%
cols = df.columns.tolist()
cols
# Out:
# ['crime_rate',
#  'proportion_res_land',
#  'proportion_business',
#  'river"',
#  'NO',
#  'avg_rooms',
#  'proportion_units',
#  'distance',
#  'accessibility',
#  'property_tax',
#  'pupil_teacher_ratio',
#  'proportion_blacks',
#  'lower_status',
#  'value']

# %%
X = df[cols[:-1]]
y = df[cols[-1]]

X_train = X.iloc[:(len(df)-50),]
y_train = y.iloc[:(len(df)-50),]

X_test = X.iloc[(len(df)-50):,]
y_test = y.iloc[(len(df)-50):,]

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
#
#  (430, 33.1219333931855),
#  (431, 33.17651639902884),
#  (432, 33.426736634087796),
#  (433, 33.54296351145934),
#  (434, 33.71388482660495),
#  (435, 33.82845096578148),
#  (436, 33.980844017759445),
#  (437, 34.15740586587352),
#  (438, 34.462105749463106),
#  (439, 34.79104739701434),
#  (440, 34.81449626652892),
#  (441, 34.87920366513953),
#  (442, 34.970822879343174),
#  (443, 35.10136488542617),
#  (444, 35.207739252089915),
#  (445, 35.303207548541856),
#  (446, 35.437855430432954),
#  (447, 35.649075482085394),
#  (448, 35.684395973174425),
#  (449, 35.66953080193054),
#  (450, 35.65038028345679),
#  (451, 35.60384785915507),
#  (452, 35.5993512207299),
#  (453, 35.55236443138458),
#  (454, 35.50104986609481),
#  (455, 35.844242654751845),
#  (456, 35.92813347376114)]

# %%
lowest_MSE = None

for each_tuple in k_MSE_tuples:
    if lowest_MSE is None:
        best_k     = each_tuple[0]
        lowest_MSE = each_tuple[1]
    else:
        if each_tuple[1] < lowest_MSE:
            best_k = each_tuple[0]
            lowest_MSE = each_tuple[1]

# Print the best MSE and k

print( "Lowest MSE for Boston dataset using k-nearest neighbors is %s, with k as %s." \
      "\n(Considering k-values in the range of 1 to %s)" % (lowest_MSE, best_k, k_list[-1]))

# print "MSE for Boston Dataset using Linear Regression is" , lowest_MSE
# Out:
# Lowest MSE for Boston dataset using k-nearest neighbors is 18.06311312711603, with k as 114.
# (Considering k-values in the range of 1 to 456)

# %% [markdown]
# #### compare with linear regression

# %%
import pandas as pd
import sklearn as sk
from sklearn import linear_model

# %%
df = pd.read_csv(r'E:\MYLEARN\2-ANALYTICS-DataScience\datasets\boston.csv')

print(df.shape)
df.head()
# Out:
# (506, 14)
#    crime_rate  proportion_res_land  proportion_business  river"     NO  \
# 0     0.00632                 18.0                 2.31       0  0.538
# 1     0.02731                  0.0                 7.07       0  0.469
# 2     0.02729                  0.0                 7.07       0  0.469
# 3     0.03237                  0.0                 2.18       0  0.458
# 4     0.06905                  0.0                 2.18       0  0.458
#
#    avg_rooms  proportion_units  distance  accessibility  property_tax  \
# 0      6.575              65.2    4.0900              1         296.0
# 1      6.421              78.9    4.9671              2         242.0
# 2      7.185              61.1    4.9671              2         242.0
# 3      6.998              45.8    6.0622              3         222.0
# 4      7.147              54.2    6.0622              3         222.0
#
#    pupil_teacher_ratio  proportion_blacks  lower_status  value
# 0                 15.3             396.90          4.98   24.0
# 1                 17.8             396.90          9.14   21.6
# 2                 17.8             392.83          4.03   34.7
# 3                 18.7             394.63          2.94   33.4
# 4                 18.7             396.90          5.33   36.2

# %%
algo = linear_model.LinearRegression()

# %%
cols = df.columns.tolist()

X = df[cols[:-1]]
y = df[cols[-1]]

X_train = X.iloc[:(len(df)-50),]
y_train = y.iloc[:(len(df)-50),]

X_test = X.iloc[(len(df)-50):,]
y_test = y.iloc[(len(df)-50):,]

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (456, 13) (456,) (50, 13) (50,)

# %%
algo.fit (X_train, y_train)
predictions = algo.predict(X_test)

MSE = sk.metrics.mean_squared_error(y_test, predictions)

print ("MSE for Boston dataset using linear regression is" , MSE)
# Out:
# MSE for Boston dataset using linear regression is 10.960410679422822

# %% [markdown]
# # We see that for this particular dataset, linear regression  outperforms k-nearest neighbors.
