# %%
# KNN - Evaluation method 2 (iris dataset)
# LOOCV
# leave one out cross validation
# keep one observation from training set as a test sample, at a time.
# repeat for all
# output - class prediction
# number of neighbors, K = 1, 3, 5, 7, 9 ...

from math import *
import operator
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 

import seaborn as sns
sns.set(style="white", color_codes=True)

# %%
# K = number of nearest neighbors for the test pattern
K1 = input('lower limit of range of k : ')
#K2 = input('upper limit of range of k : ')
# Out:
# lower limit of range of k : 3

# %%
location = r"E:\\MYLEARN\\2-ANALYTICS-DataScience\\datasets\\iris.csv"

# %%
# load the training data from iris.txt
df_iris = pd.read_csv(location)

# %%
df_iris.shape
# Out:
# (150, 5)

# %%
df_iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# add a column called 'distance'
df_iris['distance'] = 0

# %%
index = 0

# %%
df_iris.iloc[index: index+1]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class  distance
# 0           5.1          3.5           1.4          0.2  Iris-setosa         0

# %%
df_iris_trim = df_iris.drop(index)

# %%
df_iris_trim.shape
# Out:
# (149, 6)

# %%
# for each observation in the training set, as test sample

# initialize a dataframe to save all the test run results
df_loocv = pd.DataFrame()

for index, row in df_iris.iterrows():
    # save the current in the processed df_loocv
    df_loocv = df_loocv.append(df_iris.iloc[index: index+1])
    
    # drop the current row chosen as test sample
    # save it in temp df
    df_iris_trim = df_iris.drop(index)
    
    test_sepal_length = float(df_iris.loc[index, ['sepal_length']])
    test_sepal_width  = float(df_iris.loc[index, ['sepal_width']])
    test_petal_length = float(df_iris.loc[index, ['petal_length']])
    test_petal_width  = float(df_iris.loc[index, ['petal_width']])
    
    # for each row in the dataframe, calculate the distance
    for index1, row1 in df_iris_trim.iterrows():
        eucDist = sqrt(((test_sepal_length - float(row1['sepal_length'])) ** 2 +
                        (test_sepal_width - float(row1['sepal_width'])) ** 2 +
                        (test_petal_length - float(row1['petal_length'])) ** 2 +
                        (test_petal_width - float(row1['petal_width'])) ** 2))

        df_iris_trim.loc[index1, 'distance'] = eucDist
        
    # sort on distance, ascending.
    df_iris_trim.sort_values('distance', ascending=True, inplace=True)
    
    # select the first K rows, into a new df
    K = int(K1)
    df_iris_trim_K = df_iris_trim.iloc[0:K, :]
    
    # The resulting object will be in descending order so that the first element 
    # is the most frequently-occurring element. Excludes NA values by default.
    df_iris_trim_K_grouped = df_iris_trim_K['class'].value_counts()
    
    # get the first index of the resulting pandas series above (value_counts)
    pred_class = df_iris_trim_K_grouped.index[0]
    
    # save the predicated class in the test data frame
    df_loocv.loc[index, 'pred_class'] = pred_class

# %%
df_iris_trim_K['class'].value_counts()
# Out:
# Iris-virginica    3
# Name: class, dtype: int64

# %%
df_loocv
# Out:
#               class  distance  petal_length  petal_width       pred_class  \
# 0       Iris-setosa         0           1.4          0.2      Iris-setosa
# 1       Iris-setosa         0           1.4          0.2      Iris-setosa
# 138  Iris-virginica         0           4.8          1.8   Iris-virginica
# 139  Iris-virginica         0           5.4          2.1   Iris-virginica
# 140  Iris-virginica         0           5.6          2.4   Iris-virginica
# 141  Iris-virginica         0           5.1          2.3   Iris-virginica
# 142  Iris-virginica         0           5.1          1.9   Iris-virginica
# 143  Iris-virginica         0           5.9          2.3   Iris-virginica
# 144  Iris-virginica         0           5.7          2.5   Iris-virginica
# 145  Iris-virginica         0           5.2          2.3   Iris-virginica
# 146  Iris-virginica         0           5.0          1.9   Iris-virginica
# 147  Iris-virginica         0           5.2          2.0   Iris-virginica
# 148  Iris-virginica         0           5.4          2.3   Iris-virginica
# 149  Iris-virginica         0           5.1          1.8   Iris-virginica
#
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# 5             5.4          3.9
# 6             4.6          3.4
# 7             5.0          3.4
# 8             4.4          2.9
# 9             4.9          3.1
# 10            5.4          3.7
# 11            4.8          3.4
# 12            4.8          3.0
# 13            4.3          3.0
# 14            5.8          4.0
# 15            5.7          4.4
# 16            5.4          3.9
# 17            5.1          3.5
# 18            5.7          3.8
# 19            5.1          3.8
# 20            5.4          3.4
# 21            5.1          3.7
# 22            4.6          3.6
# 23            5.1          3.3
# 24            4.8          3.4
# 25            5.0          3.0
# 26            5.0          3.4
# 27            5.2          3.5
# 28            5.2          3.4
# 29            4.7          3.2
# ..            ...          ...
# 120           6.9          3.2
# 121           5.6          2.8
# 122           7.7          2.8
# 123           6.3          2.7
# 124           6.7          3.3
# 125           7.2          3.2
# 126           6.2          2.8
# 127           6.1          3.0
# 128           6.4          2.8
# 129           7.2          3.0
# 130           7.4          2.8
# 131           7.9          3.8
# 132           6.4          2.8
# 133           6.3          2.8
# 134           6.1          2.6
# 135           7.7          3.0
# 136           6.3          3.4
# 137           6.4          3.1
# 138           6.0          3.0
# 139           6.9          3.1
# 140           6.7          3.1
# 141           6.9          3.1
# 142           5.8          2.7
# 143           6.8          3.2
# 144           6.7          3.3
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 7 columns]

# %%
# find the mismatch count of class predication
no_mismatch_class = df_loocv.loc[~(df_loocv['pred_class'] == df_loocv['class'])].shape[0]
#no_mismatch_class = df_loocv.loc[~(df_loocv['pred_class'] == df_loocv['class'])]
no_mismatch_class
# Out:
# 5

# %%
df_loocv.loc[~(df_loocv['pred_class'] == df_loocv['class'])].shape[0]
# Out:
# 5

# %%
# no_mismatch_class.shape[0]

# %%
# accuracy of prediction
accuracy_pct = 100-(no_mismatch_class/ df_iris.shape[0])*100

print('Leave One Out Evaluation, Accuracy = {:6.2f} %'.format(accuracy_pct))
# Out:
# Leave One Out Evaluation, Accuracy =  96.67 %

# %%
df_loocv.loc[~(df_loocv['pred_class'] == df_loocv['class'])].shape[0]
# Out:
# 5
