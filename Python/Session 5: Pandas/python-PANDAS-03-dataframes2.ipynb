# %%
# Data Loading, Storage, and File Formats
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('E:\\MYLEARN\\2-ANALYTICS-DataScience\\datasets\\pandas_ex1.csv')

# %%
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# overriding the column names
df= pd.read_csv('E:\\MYLEARN\\2-ANALYTICS-DataScience\\datasets\\pandas_ex1.csv', 
             names=['Col1', 'Col2', 'Col3', 'Col4', 'message'])
df
# Out:
#   Col1 Col2 Col3 Col4  message
# 0    a    b    c    d  message
# 1    1    2    3    4    hello
# 2    5    6    7    8    world
# 3    9   10   11   12      foo

# %%
# No headers
df= pd.read_csv('E:\\MYLEARN\\2-ANALYTICS-DataScience\\datasets\\pandas_ex1.csv', 
             header= None)
df
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
# Suppose you wanted the message column to be the index
names = ['Col1', 'Col2', 'Col3', 'Col4', 'message']
df= pd.read_csv('E:\\MYLEARN\\2-ANALYTICS-DataScience\\datasets\\pandas_ex1.csv', 
                 names= names, index_col= 'message')
df
# Out:
#         Col1 Col2 Col3 Col4
# message
# message    a    b    c    d
# hello      1    2    3    4
# world      5    6    7    8
# foo        9   10   11   12

# %%
# Handling missing values
# Missing data is usually either not present (empty string) or marked by
# some sentinel value. By default, pandas uses a set of commonly occurring 
# sentinels, such as NA and NULL:

# %%
df = pd.read_csv('E:\\MYLEARN\\2-ANALYTICS-DataScience\\datasets\\pandas_ex2.csv')
df
# Out:
#   something    a     b     c      d message
# 0       one  1.0   2.0   3.0      4     NaN
# 1       two  5.0   6.0   NaN      8   world
# 2     three  9.0  10.0  11.0     12     foo
# 3      four  NaN   NaN   4.0  Globe     NaN
# 4      five  NaN   NaN   NaN    NaN   Earth

# %%
pd.isnull(df)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False
# 3      False   True   True  False  False     True
# 4      False   True   True   True   True    False

# %%
pd.isnull(df['a'])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: a, dtype: bool

# %%
# The na_values option can take either a list or set of strings to consider 
# missing values:
# Missing data is usually either not present (empty string) or marked by
# some sentinel value. 
# By default, pandas uses a set of commonly occurring sentinels,
# such as NA and NULL:
df = pd.read_csv('E:\\MYLEARN\\2-ANALYTICS-DataScience\\datasets\\pandas_ex1.csv', 
                 na_values=['NULL'])
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# Different NA sentinels can be specified for each column in a dict:
sentinels = {'message': ['foo', 'NA'], 'something': ['two', 'three']}
df = pd.read_csv('E:\\MYLEARN\\2-ANALYTICS\\datasets\\pandas_ex3.csv', 
                 na_values=sentinels, nrows=7)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-809ab4c2a27b> in <module>()
#       2 sentinels = {'message': ['foo', 'NA'], 'something': ['two', 'three']}
#       3 df = pd.read_csv('E:\\MYLEARN\\2-ANALYTICS\\datasets\\pandas_ex3.csv',
# ----> 4                  na_values=sentinels, nrows=7)
#       5 df
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas\_libs\parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas\_libs\parsers.c:8873)()
#
# FileNotFoundError: File b'E:\\MYLEARN\\2-ANALYTICS\\datasets\\pandas_ex3.csv' does not exist

# %%
# Data Cleaning and Preparation
from numpy import nan as NA
df = pd.DataFrame([[1., 6.5, 3.], 
                     [1.,NA ,NA ],
                     [NA,NA ,NA ], 
                     [NA, 6.5, 3.]])
df
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
# dropna by default drops any row containing a missing value:
df.dropna()
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
# Passing how='all' will only drop rows that are all NA:
df.dropna(how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df = pd.DataFrame(np.random.randn(7, 3))
df
# Out:
#           0         1         2
# 0 -1.333158  2.521131  1.232129
# 1 -1.249939  0.308228 -0.452659
# 2 -0.153742 -1.464652  0.652946
# 3 -1.794587  0.521595  0.208709
# 4 -0.260902  0.059667 -1.540081
# 5 -1.871605  0.564977  0.619591
# 6 -0.705568  1.282251  0.989663

# %%
# upto first 3 rows and col  = 1
df.iloc[:4, 1] = NA
df
# Out:
#           0         1         2
# 0 -1.333158       NaN  1.232129
# 1 -1.249939       NaN -0.452659
# 2 -0.153742       NaN  0.652946
# 3 -1.794587       NaN  0.208709
# 4 -0.260902  0.059667 -1.540081
# 5 -1.871605  0.564977  0.619591
# 6 -0.705568  1.282251  0.989663

# %%
df.iloc[:2, 2] = NA
df
# Out:
#           0         1         2
# 0 -1.333158       NaN       NaN
# 1 -1.249939       NaN       NaN
# 2 -0.153742       NaN  0.652946
# 3 -1.794587       NaN  0.208709
# 4 -0.260902  0.059667 -1.540081
# 5 -1.871605  0.564977  0.619591
# 6 -0.705568  1.282251  0.989663

# %%
df.dropna()
# Out:
#           0         1         2
# 4 -0.260902  0.059667 -1.540081
# 5 -1.871605  0.564977  0.619591
# 6 -0.705568  1.282251  0.989663

# %%
# Filling In Missing Data
df
df.fillna(0)
# Out:
#           0         1         2
# 0 -1.333158  0.000000  0.000000
# 1 -1.249939  0.000000  0.000000
# 2 -0.153742  0.000000  0.652946
# 3 -1.794587  0.000000  0.208709
# 4 -0.260902  0.059667 -1.540081
# 5 -1.871605  0.564977  0.619591
# 6 -0.705568  1.282251  0.989663

# %%
# fillna returns a new object, but you can modify the existing object in-place
df
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df.fillna(0, inplace=True)
df
# Out:
#           0         1         2
# 0  0.847212  0.000000  0.000000
# 1 -0.187127  0.000000  0.000000
# 2 -0.136450  0.000000 -0.728593
# 3  0.183284  0.000000 -0.585722
# 4 -0.005329 -0.462178  0.819565
# 5 -0.359254 -0.326439 -0.539893
# 6 -0.655097 -0.844486 -0.059065

# %%
# interpolation methods
df = pd.DataFrame(np.random.randn(6, 3))
df
# Out:
#           0         1         2
# 0 -0.353015 -0.315459  0.239995
# 1  1.674924  0.184732 -2.165036
# 2  1.303310  0.443690 -1.010638
# 3  0.850334 -0.415808  0.085867
# 4 -0.383253 -1.942323  0.511535
# 5  0.938564 -1.016190  0.647351

# %%
df.iloc[2:, 1] = NA
df.iloc[4:, 2] = NA
df
# Out:
#           0         1         2
# 0 -0.353015 -0.315459  0.239995
# 1  1.674924  0.184732 -2.165036
# 2  1.303310       NaN -1.010638
# 3  0.850334       NaN  0.085867
# 4 -0.383253       NaN       NaN
# 5  0.938564       NaN       NaN

# %%
df.fillna(method='ffill')
# Out:
#           0         1         2
# 0 -0.353015 -0.315459  0.239995
# 1  1.674924  0.184732 -2.165036
# 2  1.303310  0.184732 -1.010638
# 3  0.850334  0.184732  0.085867
# 4 -0.383253  0.184732  0.085867
# 5  0.938564  0.184732  0.085867

# %%
# Removing Duplicates
df = pd.DataFrame([[1,3],
                  [3,4],
                  [1,3],
                  [5,7],
                  [6,9],
                  [1,6],
                  [1,3]])
                
df
# Out:
#    0  1
# 0  1  3
# 1  3  4
# 2  1  3
# 3  5  7
# 4  6  9
# 5  1  6
# 6  1  3

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
# drop_duplicates returns a DataFrame where the duplicated array is False:
df.drop_duplicates()
# Out:
#    0  1
# 0  1  3
# 1  3  4
# 3  5  7
# 4  6  9
# 5  1  6

# %%
# duplicated and drop_duplicates by default keep the first observed value 
# combination.Passing keep='last' will return the last one:
df.drop_duplicates(keep='last')
# Out:
#    0  1
# 1  3  4
# 3  5  7
# 4  6  9
# 5  1  6
# 6  1  3
